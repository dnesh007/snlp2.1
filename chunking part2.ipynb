# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
train_text = state_union.raw("C:/Pierce_1853.txt")
sample_text = state_union.raw("C:/Pierce_1854.txt")

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

# %%
tokenized = custom_sent_tokenizer.tokenize(sample_text)

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            result=chunkParser.parse(nltk.pos_tag(train_text))
            print(result)
            chunked.draw()     
    except Exception as e:
        print(str(e))

process_content()
# Out:
# (S
#   (Chunk F/NNP e/NN)
#   l/NN
#   l/NN
#   o/NN
#   w/SYM
#   -/:
#   C/NN
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP S/NNP)
#   e/VBZ
#   n/FW
#   a/DT
#   t/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP H/NNP)
#   o/MD
#   u/VB
#   s/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP R/NNP e/NN)
#   p/NN
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   n/JJ
#   t/VBZ
#   a/DT
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   s/NN
#   :/:
#
# /JJ
#   (Chunk
# /NNP T/NNP h/NN)
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#   t/NN
#   e/NN
#   r/NN
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   o/IN
#   p/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP R/NNP e/NN)
#   p/NN
#   u/NN
#   b/IN
#   l/NN
#   i/NN
#   c/VBP
#    /PDT
#   a/DT
#   n/JJ
#   t/NN
#   i/NN
#   c/VBP
#   i/NN
#   p/VBP
#   a/DT
#   t/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#
# /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   e/NN
#   m/NN
#   b/IN
#   l/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   l/NN
#   f/NN
#   i/NN
#   l/VBP
#   l/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   c/JJ
#   c/VB
#   a/DT
#   s/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   y/NN
#
# /NN
#   i/NN
#   m/VBP
#   p/NN
#   o/NN
#   s/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#    /VBZ
#   a/DT
#    /JJ
#   n/NN
#   e/NN
#   w/NN
#   (Chunk  /NNP P/NNP r/NN)
#   e/NN
#   s/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   t/NN
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   o/NN
#   n/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP e/NN)
#   v/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   (Chunk r/VBP  /NNP)
#   c/VBP
#   a/DT
#   p/NN
#   a/DT
#   c/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk
# /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/VBZ
#   a/DT
#   l/NN
#   i/NN
#   z/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   p/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   u/JJ
#   n/JJ
#   d/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#    /JJ
#   p/NN
#   o/IN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP s/NN)
#   y/NN
#   s/NN
#   t/NN
#   e/NN
#   m/NN
#    /VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   c/NNS
#   e/VBP
#    /JJ
#   c/NN
#   o/NN
#   m/NN
#   p/NN
#   l/NN
#   e/NN
#   (Chunk x/NNP)
#
# /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   y/NN
#   m/NN
#   m/NN
#   e/NN
#   t/IN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#   ./.
#    /CC
#   (Chunk W/NNP)
#   h/VBP
#   i/JJ
#   l/VBP
#   e/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   f/VBP
#   f/NN
#   e/NN
#   r/NN
#   e/NN
#   n/JJ
#   t/NN
#    /NN
#   b/NN
#   r/NN
#   a/DT
#   n/JJ
#   c/NN
#   h/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP G/NNP)
#   o/MD
#   v/VB
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#    /VBD
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#
# /JJ
#   c/NN
#   e/NN
#   r/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP t/NN)
#   e/NN
#   n/JJ
#   t/NN
#    /NN
#   i/NN
#   n/VBP
#   d/NN
#   e/NN
#   p/NN
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP)
#   e/VBZ
#   a/DT
#   c/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#    /VBZ
#   a/DT
#   l/NN
#   i/NN
#   k/VBP
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk
# /NNP d/NN)
#   i/NN
#   r/VBP
#   e/NN
#   c/NNS
#   t/VBP
#    /JJ
#   r/NN
#   e/NN
#   f/NN
#   e/NN
#   r/NN
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   u/JJ
#   r/NN
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP p/NN)
#   o/NN
#   w/NN
#   e/NN
#   r/NN
#   ./.
#    /CC
#   (Chunk F/NNP)
#   o/VBP
#   r/NN
#   t/NN
#   u/JJ
#   n/VBZ
#   a/DT
#   t/NN
#   e/NN
#   l/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   d/VBP
#   e/JJ
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   s/NN
#   y/NN
#   s/NN
#   t/NN
#   e/NN
#   m/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk
# /NNP m/NN)
#   a/DT
#   n/JJ
#    /NN
#   i/NN
#   s/VBP
#    /JJ
#   s/NN
#   o/NN
#   (Chunk  /NNP h/NN)
#   i/NN
#   g/VBP
#   h/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   n/JJ
#   e/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/NN
#   b/NN
#   l/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   c/VB
#   a/DT
#   l/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP p/NN)
#   u/NN
#   b/IN
#   l/NN
#   i/NN
#   c/VBP
#    /JJ
#   s/NN
#   t/VBD
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/RB
#    /VBP
#   a/DT
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk
# /NNP e/NN)
#   s/NN
#   c/VBZ
#   a/DT
#   p/JJ
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   c/NN
#   r/NN
#   u/JJ
#   t/NN
#   i/NN
#   n/VBP
#   y/NN
#    /NN
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP)
#   e/VBZ
#   m/JJ
#   p/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   p/NN
#   o/NN
#   n/IN
#   s/NN
#   i/NN
#   b/VBP
#   i/NN
#   l/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /FW
#   a/DT
#   l/NN
#   l/NN
#   (Chunk
# /NNP)
#   o/VBZ
#   f/JJ
#   f/NN
#   i/NN
#   c/VBP
#   i/VB
#   a/DT
#   l/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   n/JJ
#   c/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#    /NN
#   i/NN
#   m/VBP
#   p/NN
#   l/NN
#   y/NN
#   ./.
#
# /CC
#
# /JJ
#   (Chunk U/NNP p/NN)
#   o/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP j/NN)
#   u/JJ
#   s/NN
#   t/NN
#   i/NN
#   c/VBP
#   e/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   l/NN
#   l/NN
#   i/NN
#   g/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   s/JJ
#   s/NN
#   e/NN
#   s/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /PDT
#   a/DT
#    /JJ
#   g/NN
#   o/NN
#   v/NN
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   u/JJ
#   s/NN
#   (Chunk
# /NNP)
#   o/VBZ
#   r/NN
#   g/NN
#   a/DT
#   n/NN
#   i/NN
#   z/VBP
#   e/NN
#   d/NN
#   ,/,
#    /VBP
#   i/JJ
#   s/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/NN
#   i/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   f/NN
#   e/NN
#   d/NN
#   e/NN
#   r/VBZ
#   a/DT
#   c/JJ
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   l/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk
# /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   n/JJ
#   e/NN
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   n/JJ
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/NN
#   o/IN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#    /NN
#   i/NN
#   t/VBP
#   s/JJ
#    /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   r/NN
#   e/NN
#   s/NN
#   t/NN
#   s/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#   u/JJ
#   r/NN
#   p/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#
# /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   c/JJ
#   r/NN
#   o/IN
#   a/DT
#   c/NN
#   h/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP p/NN)
#   o/NN
#   w/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   a/DT
#   u/JJ
#   l/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP p/NN)
#   e/NN
#   r/NN
#   s/NN
#   o/NN
#   n/IN
#   a/DT
#   l/NN
#
# /VBZ
#   a/DT
#   m/NN
#   b/NN
#   i/NN
#   t/VBP
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   n/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   ./.
#
# /CC
#
# /JJ
#   (Chunk T/NNP h/NN)
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#   t/NN
#   e/NN
#   r/NN
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /NN
#   I/PRP
#    /VBP
#   h/PDT
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   p/NN
#   o/NN
#   k/NN
#   e/FW
#   n/JJ
#    /NN
#   i/NN
#   s/VBP
#    /NN
#   i/NN
#   n/VBP
#   s/NN
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#    /VBP
#   a/DT
#   n/JJ
#    /NN
#   i/NN
#   n/VBP
#   q/NN
#   u/NN
#   i/NN
#   r/VBP
#   i/NN
#   n/VBP
#   g/NN
#   ,/,
#   (Chunk
# /NNP)
#   s/VBD
#   e/JJ
#   l/NN
#   f/SYM
#   -/:
#   g/NN
#   o/JJ
#   v/NN
#   e/NN
#   r/NN
#   n/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NNS
#   m/VBP
#   u/JJ
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   u/NN
#   t/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   i/NN
#   m/VBP
#   u/JJ
#   l/NN
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#   ,/,
#   (Chunk  /NNP)
#   d/VBZ
#   o/JJ
#   u/JJ
#   b/NN
#   t/NN
#   l/NN
#   e/NN
#   s/NN
#   s/NN
#   ,/,
#    /VB
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   i/NN
#   m/VBP
#   e/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk
# /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   s/JJ
#   e/NN
#   t/NN
#   t/NN
#   l/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   d/NN
#   i/NN
#   t/VBP
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   v/NN
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   e/NN
#   i/NN
#   g/VBP
#   n/JJ
#   (Chunk  /NNP p/NN)
#   o/NN
#   w/NN
#   e/NN
#   r/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   y/NN
#   (Chunk
# /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   w/NN
#   (Chunk  /NNP o/NN)
#   b/NN
#   l/NN
#   i/NN
#   g/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   u/JJ
#   l/NN
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   f/NN
#   r/NN
#   o/IN
#   m/NN
#    /VBP
#   a/DT
#    /JJ
#   s/NN
#   u/JJ
#   d/NN
#   d/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP t/NN)
#   e/NN
#   n/IN
#   s/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   e/VBP
#   l/NN
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk
# /NNP e/NN)
#   n/RB
#   t/JJ
#   e/NN
#   r/NN
#   p/NN
#   r/NN
#   i/NN
#   s/VBP
#   e/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   p/NN
#   i/NN
#   r/VBP
#   i/NN
#   t/VBP
#    /IN
#   w/NN
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   e/VBP
#   l/NN
#   d/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP e/NN)
#   n/RB
#   t/JJ
#   e/NN
#   r/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#
# /VBZ
#   a/DT
#   m/NN
#   a/DT
#   z/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP e/NN)
#   n/NN
#   e/NN
#   r/NN
#   g/NN
#   y/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   o/NN
#   u/JJ
#   r/NN
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   e/IN
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   m/VBD
#   a/DT
#   n/JJ
#   d/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP h/NN)
#   u/JJ
#   m/VBZ
#   a/DT
#   n/NN
#   i/NN
#   t/VBP
#   y/NN
#
# /NN
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/NN
#   e/NN
#   l/NN
#   o/NN
#   p/NN
#   e/NN
#   d/NN
#   ./.
#
# /JJ
#
# /VBD
#   A/DT
#   l/NN
#   t/NN
#   h/NN
#   o/JJ
#   u/JJ
#   g/NN
#   h/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   s/VBP
#   e/VBZ
#   a/DT
#   s/JJ
#   e/NN
#   ,/,
#    /VB
#   a/DT
#   s/JJ
#   s/NN
#   u/JJ
#   m/NN
#   i/NN
#   n/VBP
#   g/NN
#    /VBP
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   e/NN
#   (Chunk  /NNP t/NN)
#   i/NN
#   m/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   h/VB
#   a/DT
#   r/NN
#   a/DT
#   c/NN
#   t/NN
#   e/IN
#   r/NN
#   i/NN
#   s/VBP
#   t/NN
#   i/NN
#   c/VBP
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#    /JJ
#   w/NN
#   i/NN
#   d/VBP
#   e/NN
#   s/NN
#   p/NN
#   r/NN
#   e/VBZ
#   a/DT
#   d/NN
#
# /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   v/IN
#   a/DT
#   s/JJ
#   t/NN
#   a/DT
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   s/VBD
#   t/NN
#   i/NN
#   l/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/JJ
#    /NN
#   l/NN
#   e/NN
#   f/NN
#   t/IN
#    /NN
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP)
#   s/VBZ
#   a/DT
#   d/NN
#    /NN
#   t/NN
#   r/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP s/NN)
#   o/NN
#   m/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   r/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk
# /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   n/NN
#   t/NN
#   r/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP)
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   b/NN
#   u/JJ
#   n/JJ
#   d/NN
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   u/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   v/NN
#   e/NN
#   r/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk
# /NNP t/NN)
#   h/VBD
#   a/DT
#   n/JJ
#   k/NN
#   f/NN
#   u/JJ
#   l/NN
#   n/JJ
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP G/NNP)
#   o/MD
#   (Chunk d/VB  /NNP f/NN)
#   o/NN
#   r/NN
#    /VBZ
#   a/DT
#   n/JJ
#    /NN
#   a/DT
#   c/JJ
#   c/NN
#   u/JJ
#   m/NN
#   u/JJ
#   l/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   g/VBP
#   n/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP m/NN)
#   e/NN
#   r/NN
#   c/NN
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP s/NN)
#   h/NN
#   o/JJ
#   w/NN
#   e/NN
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP u/NN)
#   s/NN
#
# /VBZ
#   a/DT
#   s/JJ
#    /NN
#   a/DT
#    /JJ
#   n/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ./.
#    /NN
#   I/PRP
#   t/VBP
#    /JJ
#   i/NN
#   s/VBP
#    /JJ
#   w/NN
#   e/NN
#   l/NN
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#    /VBZ
#   a/DT
#    /JJ
#   c/NN
#   o/NN
#   n/JJ
#   s/JJ
#   c/NN
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   n/JJ
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP r/NN)
#   a/DT
#   p/NN
#   i/NN
#   d/VBP
#    /PDT
#   a/DT
#   d/NN
#   v/NN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#
# /NN
#   i/NN
#   n/VBP
#   c/NN
#   r/NN
#   e/VBZ
#   a/DT
#   s/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   g/NN
#   t/NN
#   h/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   b/NN
#   i/NN
#   t/VBP
#   u/IN
#   a/DT
#   l/NN
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#   s/JJ
#   s/NN
#   o/IN
#   c/NN
#   i/VBP
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#    /VBP
#   a/DT
#   n/JJ
#    /NN
#   a/DT
#   b/NN
#   i/NN
#   d/VBP
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk
# /NNP d/NN)
#   e/NN
#   p/NN
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP H/NNP)
#   i/JJ
#   m/VBP
#    /JJ
#   w/NN
#   h/NN
#   o/JJ
#   (Chunk  /NNP h/NN)
#   o/NN
#   l/NN
#   d/NN
#   s/NN
#    /NN
#   i/NN
#   n/VBP
#    /IN
#   (Chunk H/NNP)
#   i/JJ
#   s/VBP
#    /JJ
#   h/NN
#   a/DT
#   n/JJ
#   d/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   s/JJ
#   t/NN
#   i/NN
#   n/VBP
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP m/NN)
#   e/NN
#   n/JJ
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk
# /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   ./.
#
# /CC
#
# /JJ
#   (Chunk R/NNP e/NN)
#   c/NN
#   o/NN
#   g/NN
#   n/NN
#   i/NN
#   z/VBP
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   s/VBP
#   d/NN
#   o/NN
#   m/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   r/NN
#   o/IN
#   a/DT
#   d/NN
#    /NN
#   p/NN
#   r/NN
#   i/NN
#   n/VBP
#   c/NN
#   i/NN
#   p/VBP
#   l/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /FW
#   a/DT
#   b/NN
#   s/NN
#   o/NN
#   l/NN
#   u/JJ
#   t/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/NN
#   i/NN
#   g/VBP
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   (Chunk
# /NNP t/NN)
#   o/NN
#   l/NN
#   e/NN
#   r/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   c/JJ
#   l/NN
#   a/DT
#   i/JJ
#   m/NN
#   e/NN
#   d/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP f/NN)
#   u/JJ
#   n/JJ
#   d/NN
#   a/DT
#   m/NN
#   e/NN
#   n/JJ
#   t/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   w/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   j/NN
#   o/NN
#   i/VBP
#   c/VBP
#   i/JJ
#   n/VBP
#   g/JJ
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   n/NN
#   i/NN
#   g/VBP
#   n/IN
#
# /NN
#   i/NN
#   n/VBP
#   f/JJ
#   l/NN
#   u/JJ
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /NN
#   i/NN
#   t/VBP
#    /NN
#   h/NN
#   a/DT
#   s/JJ
#    /NN
#   e/NN
#   (Chunk x/NNP e/NN)
#   r/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP s/NN)
#   o/IN
#   c/NN
#   i/VBP
#   a/DT
#   l/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   d/NN
#   i/NN
#   t/VBP
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#    /VBP
#   I/PRP
#
# /VBP
#   s/JJ
#   h/NN
#   o/NN
#   u/JJ
#   l/NN
#   d/NN
#   (Chunk  /NNP s/NN)
#   h/NN
#   r/NN
#   i/NN
#   n/VBP
#   k/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#    /VBP
#   a/DT
#    /JJ
#   c/NN
#   l/NN
#   e/VBZ
#   a/DT
#   r/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   d/VBP
#    /NN
#   I/PRP
#    /VBP
#   f/VB
#   a/DT
#   i/NN
#   l/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   e/NN
#   p/NN
#   e/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   v/NN
#   i/NN
#   c/VBP
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk
# /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP w/NN)
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   n/JJ
#    /NN
#   p/NN
#   l/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/NN
#   i/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#    /VBZ
#   a/DT
#   n/JJ
#   y/NN
#    /VBD
#   a/DT
#   p/NN
#   p/NN
#   a/DT
#   r/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   g/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#    /NN
#   i/NN
#   f/VBP
#    /NN
#   i/NN
#   t/VBP
#    /NN
#   b/NN
#   e/NN
#   (Chunk
# /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   s/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   l/NN
#    /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   g/NN
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#   ,/,
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/VBD
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#    /NN
#   t/NN
#   r/NN
#   u/JJ
#   t/NN
#   h/NN
#   s/NN
#    /VBZ
#   a/DT
#   f/JJ
#   f/NN
#   i/NN
#   r/VBP
#   m/NN
#   e/NN
#   d/NN
#
# /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   i/NN
#   l/VBP
#   l/NN
#   u/JJ
#   s/NN
#   t/NN
#   r/VBZ
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   v/VBP
#   i/NN
#   n/VBP
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   v/NN
#   e/NN
#   l/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ./.
#    /NN
#   I/PRP
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   d/VBP
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   r/NN
#   r/NN
#   o/NN
#   w/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#
# /VBZ
#   a/DT
#   f/JJ
#   f/NN
#   l/NN
#   i/NN
#   c/VBP
#   t/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   f/NN
#   f/NN
#   e/NN
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   ,/,
#    /VBP
#   i/JJ
#   t/VBP
#    /JJ
#   h/NN
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP c/NN)
#   o/NN
#   n/JJ
#   s/NN
#   o/IN
#   l/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   w/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/IN
#   m/NN
#   p/NN
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   s/VBP
#   a/DT
#   s/NN
#   t/NN
#   e/NN
#   r/NN
#   (Chunk
# /NNP)
#   m/VBZ
#   a/DT
#   d/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   u/JJ
#   e/NN
#   (Chunk  /NNP)
#   n/IN
#   e/NN
#   i/NN
#   g/VBP
#   h/NN
#   b/NN
#   o/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP d/NN)
#   i/NN
#   s/VBP
#   t/IN
#   r/NN
#   i/NN
#   c/VBP
#   t/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP s/NN)
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   d/VBP
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP)
#   e/VBZ
#   a/DT
#   c/NN
#   h/NN
#   (Chunk
# /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP c/NN)
#   h/NN
#   e/NN
#   e/IN
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   t/JJ
#   c/NN
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   g/NN
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NNS
#   m/VBP
#   o/JJ
#   n/JJ
#    /NN
#   b/NN
#   o/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#
# /NN
#   b/NN
#   r/NN
#   o/NN
#   t/NN
#   h/NN
#   e/NN
#   r/NN
#   h/NN
#   o/JJ
#   o/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP u/NN)
#   n/NN
#   i/NN
#   t/VBP
#   e/NN
#   s/NN
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP h/NN)
#   e/VBZ
#   a/DT
#   r/NN
#   t/NN
#   s/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /PDT
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   (Chunk U/NNP n/NN)
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   h/JJ
#   e/NN
#   n/JJ
#   (Chunk
# /NNP d/NN)
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   e/NN
#   n/JJ
#   s/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#    /VBP
#   a/DT
#   b/NN
#   r/NN
#   o/IN
#   a/DT
#   d/NN
#    /NN
#   o/NN
#   r/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   l/NN
#   a/DT
#   m/NN
#   i/NN
#   t/VBP
#   y/NN
#    /NN
#   i/NN
#   m/VBP
#   p/NN
#   e/NN
#   n/JJ
#   d/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   v/FW
#   e/FW
#   r/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#    /VBD
#   a/DT
#   t/NN
#    /NN
#   h/NN
#   o/JJ
#   m/NN
#   e/NN
#   ./.
#
# /CC
#
# /JJ
#   (Chunk O/NNP u/NN)
#   r/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   p/VBP
#   l/NN
#   o/NN
#   m/VBD
#   a/DT
#   t/NN
#   i/NN
#   c/VBP
#    /JJ
#   r/NN
#   e/NN
#   l/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   e/NN
#   i/NN
#   g/VBP
#   n/JJ
#   (Chunk  /NNP p/NN)
#   o/NN
#   w/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   d/VBP
#   e/JJ
#   r/NN
#   g/NN
#   o/NN
#   n/JJ
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   (Chunk  /NNP e/NN)
#   s/NN
#   s/NN
#   e/NN
#   n/IN
#   t/NN
#   i/VBP
#   a/DT
#   l/NN
#   (Chunk
# /NNP)
#   c/VBZ
#   h/VB
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   n/VBP
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   d/JJ
#   j/NN
#   o/NN
#   u/JJ
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   ./.
#    /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   m/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   m/NN
#   (Chunk
# /NNP q/NN)
#   u/JJ
#   e/NN
#   s/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#    /JJ
#   d/NN
#   i/NN
#   s/VBP
#   t/NN
#   u/JJ
#   r/NN
#   b/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   c/VBZ
#   h/VB
#   a/DT
#   r/NN
#   a/DT
#   c/NN
#   t/NN
#   e/NN
#   r/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   t/NN
#   i/NN
#   l/VBP
#   l/NN
#   (Chunk  /NNP p/NN)
#   e/NN
#   n/IN
#   d/NN
#   i/NN
#   n/VBP
#   g/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   u/NN
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP g/NN)
#   o/NN
#   o/NN
#   d/NN
#   (Chunk
# /NNP r/NN)
#   e/VBZ
#   a/DT
#   s/JJ
#   o/NN
#   n/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /NN
#   b/NN
#   e/NN
#   l/NN
#   i/NN
#   e/VBP
#   v/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   y/NN
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#    /NN
#   b/NN
#   e/NN
#    /VBZ
#   a/DT
#   m/NN
#   i/NN
#   c/VBP
#   a/DT
#   b/NN
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#   d/JJ
#   j/NN
#   u/JJ
#   s/NN
#   t/NN
#   e/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk F/NNP o/NN)
#   r/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   m/NN
#   e/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   s/NN
#   (Chunk
# /NNP)
#   p/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   (Chunk  /NNP G/NNP r/NN)
#   e/VBZ
#   a/DT
#   t/NN
#    /NN
#   (Chunk B/NNP r/NN)
#   i/NN
#   t/VBP
#   a/DT
#   i/NN
#   n/MD
#    /VB
#   h/VB
#   a/DT
#   s/JJ
#    /NN
#   s/NN
#   o/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   s/NN
#   t/NN
#   r/NN
#   u/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   r/VBP
#   s/NN
#   t/NN
#    /VBZ
#   a/DT
#   r/NN
#   t/NN
#   i/NN
#   c/VBP
#   l/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   v/NN
#   e/NN
#   n/IN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk
# /NNP t/NN)
#   h/NN
#   e/NN
#    /VBD
#   2/CD
#   0/CD
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   A/DT
#   p/NN
#   r/NN
#   i/NN
#   l/NN
#   ,/,
#    /VBD
#   1/CD
#   8/CD
#   1/CD
#   8/CD
#   ,/,
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   r/NN
#   e/NN
#   g/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   s/VBP
#   h/NN
#   e/NN
#   r/NN
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP o/NN)
#   n/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP n/NN)
#   o/NN
#   r/NN
#   t/NN
#   h/NN
#   e/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   e/NN
#   r/NN
#   n/JJ
#   (Chunk
# /NNP c/NN)
#   o/VBD
#   a/DT
#   s/NN
#   t/NN
#   ,/,
#    /VB
#   a/DT
#   s/JJ
#    /NN
#   t/NN
#   o/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP)
#   c/VBZ
#   l/JJ
#   u/JJ
#   d/NN
#   e/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/JJ
#   s/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   m/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   s/VBP
#   h/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   g/NN
#   r/NN
#   o/NN
#   u/JJ
#   n/JJ
#   d/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk
# /NNP t/NN)
#   h/NN
#   e/NN
#   y/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   e/NN
#   e/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   o/NN
#   r/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP)
#   n/RB
#   e/VBZ
#   a/DT
#   r/NN
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#    /JJ
#   q/NN
#   u/IN
#   a/DT
#   r/NN
#   t/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#    /JJ
#   c/NN
#   e/NN
#   n/JJ
#   t/NN
#   u/JJ
#   r/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   u/NN
#   b/NN
#   s/NN
#   e/NN
#   q/NN
#   u/JJ
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk
# /NNP)
#   d/VBZ
#   a/DT
#   t/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#    /NN
#   t/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/JJ
#   y/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   v/NN
#   e/NN
#   r/NN
#    /VBZ
#   a/DT
#   c/JJ
#   q/NN
#   u/NN
#   i/NN
#   e/VBP
#   s/JJ
#   c/NN
#   e/NN
#   d/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   i/JJ
#   s/VBP
#
# /JJ
#   c/NN
#   o/NN
#   n/JJ
#   s/NN
#   t/NN
#   r/NN
#   u/JJ
#   c/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   u/NN
#   t/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   l/NN
#   w/WRB
#   a/DT
#   y/NN
#   s/NN
#   (Chunk  /NNP)
#   c/VBZ
#   l/VBZ
#   a/DT
#   i/JJ
#   m/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   r/VBP
#    /IN
#   f/NN
#   i/NN
#   s/VBP
#   h/NN
#   e/NN
#   r/NN
#   m/NN
#   e/NN
#   n/JJ
#    /VBZ
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   s/NN
#   (Chunk
# /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   y/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   d/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP l/NN)
#   o/NN
#   n/JJ
#   g/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   j/JJ
#   o/NN
#   y/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   o/NN
#   u/JJ
#   t/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   l/NN
#   e/NN
#   s/NN
#   t/VBD
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ./.
#    /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#    /VBP
#   a/DT
#    /JJ
#   v/NN
#   i/NN
#   e/VBP
#   w/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   m/NN
#   o/NN
#   v/NN
#   e/NN
#
# /VBZ
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP d/NN)
#   i/NN
#   f/VBP
#   f/NN
#   i/NN
#   c/VBP
#   u/JJ
#   l/NN
#   t/NN
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk  /NNP o/NN)
#   n/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   u/NN
#   b/NN
#   j/NN
#   e/NN
#   c/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   t/VBZ
#   o/JJ
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP t/NN)
#   e/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   s/VBP
#   h/NN
#   e/NN
#   r/NN
#   m/NN
#   e/NN
#   n/JJ
#
# /NN
#   b/NN
#   e/NN
#   y/NN
#   o/NN
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   m/VBP
#   i/NN
#   t/VBP
#   s/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   x/VBP
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   v/NN
#   e/NN
#   n/IN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#    /VBD
#   1/CD
#   8/CD
#   1/CD
#   8/CD
#   ,/,
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   g/NN
#   u/JJ
#   l/NN
#   a/DT
#   t/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   a/DT
#   d/NN
#   e/NN
#   (Chunk
# /NNP b/NN)
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP B/NNP r/NN)
#   i/NN
#   t/VBP
#   i/NN
#   s/VBP
#   h/NN
#   (Chunk  /NNP N/NNP)
#   o/MD
#   r/VB
#   t/NN
#   h/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   n/JJ
#    /NN
#   (Chunk P/NNP r/NN)
#   o/NN
#   v/NN
#   i/NN
#   n/VBP
#   c/NN
#   e/NN
#   s/NN
#   ,/,
#    /VB
#   a/DT
#
# /JJ
#   n/NN
#   e/NN
#   g/NN
#   o/IN
#   t/NN
#   i/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP h/NN)
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP o/NN)
#   p/NN
#   e/NN
#   n/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#    /VBP
#   a/DT
#    /NN
#   f/VBZ
#   a/DT
#   i/JJ
#   r/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   s/NN
#   p/NN
#   e/NN
#   c/VBP
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#    /JJ
#   f/NN
#   a/DT
#   v/NN
#   o/NN
#   r/NN
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   u/JJ
#   l/NN
#   t/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   (Chunk o/VBP
# /NNP p/NN)
#   r/NN
#   o/NN
#   t/NN
#   e/NN
#   c/VBP
#   t/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   s/VBP
#   h/NN
#   e/NN
#   r/NN
#   m/NN
#   e/NN
#   n/IN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   j/JJ
#   o/NN
#   y/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   i/NN
#   r/VBP
#    /IN
#   r/NN
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   v/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk
# /NNP)
#   c/VBZ
#   o/JJ
#   l/NN
#   l/NN
#   i/NN
#   s/VBP
#   i/NN
#   o/VBP
#   n/JJ
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   m/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   (Chunk B/NNP r/NN)
#   i/NN
#   t/VBP
#   i/NN
#   s/VBP
#   h/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   s/VBP
#   h/NN
#   e/NN
#   r/NN
#   m/NN
#   e/NN
#   n/NN
#   ,/,
#    /VBP
#   I/PRP
#    /VBP
#   d/JJ
#   e/NN
#   e/NN
#   m/NN
#   e/NN
#   d/NN
#    /NN
#   i/NN
#   t/VBP
#    /JJ
#   e/NN
#   (Chunk x/NNP p/NN)
#   e/NN
#   d/NN
#   i/NN
#   e/VBP
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk
# /NNP)
#   s/VBZ
#   t/VB
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/RB
#    /VBP
#   a/DT
#    /NN
#   n/IN
#   a/DT
#   v/NN
#   a/DT
#   l/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   c/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#    /JJ
#   t/NN
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP q/NN)
#   u/VBD
#   a/DT
#   r/NN
#   t/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   r/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   i/NN
#   s/VBP
#   h/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   s/VBZ
#   e/VB
#   a/DT
#   s/JJ
#   o/NN
#   n/NN
#   ./.
#
# /CC
#
# /JJ
#   (Chunk E/NNP m/NN)
#   b/NN
#   a/DT
#   r/NN
#   r/NN
#   a/DT
#   s/JJ
#   s/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP q/NN)
#   u/JJ
#   e/NN
#   s/NN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   l/NN
#   s/NN
#   o/NN
#    /VBZ
#   a/DT
#   r/NN
#   i/NN
#   s/VBP
#   e/NN
#   n/NN
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   w/NN
#   o/NN
#   (Chunk  /NNP G/NNP)
#   o/MD
#   v/VB
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   s/NN
#    /NN
#   i/NN
#   n/VBP
#
# /JJ
#   r/NN
#   e/NN
#   g/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP C/NNP e/NN)
#   n/NN
#   t/NN
#   r/VBZ
#   a/DT
#   l/NN
#   (Chunk  /VBZ A/NNP m/NN)
#   e/NN
#   r/NN
#   i/NN
#   c/VBP
#   a/DT
#   ./.
#    /NN
#   (Chunk G/NNP r/NN)
#   e/VBZ
#   a/DT
#   t/NN
#    /NN
#   (Chunk B/NNP r/NN)
#   i/NN
#   t/VBP
#   a/DT
#   i/NN
#   n/MD
#    /VB
#   h/VB
#   a/DT
#   s/JJ
#    /NN
#   p/NN
#   r/NN
#   o/NN
#   p/NN
#   o/NN
#   s/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   t/NN
#   t/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   m/NN
#    /NN
#   b/NN
#   y/NN
#    /VBZ
#   a/DT
#   n/JJ
#
# /NN
#   a/DT
#   m/NN
#   i/NN
#   c/VBP
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#    /VBZ
#   a/DT
#   r/NN
#   r/NN
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   n/VBP
#   i/NN
#   s/VBP
#   t/NN
#   e/NN
#   r/NN
#    /VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP L/NNP)
#   o/MD
#   n/VB
#   d/JJ
#   o/NN
#   n/IN
#    /NN
#   i/NN
#   s/VBP
#    /NN
#   i/NN
#   n/VBP
#   s/NN
#   t/NN
#   r/NN
#   u/JJ
#   c/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   t/JJ
#   e/NN
#   r/NN
#
# /NN
#   i/NN
#   n/VBP
#   t/NN
#   o/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   g/NN
#   o/IN
#   t/NN
#   i/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP s/NN)
#   u/NN
#   b/NN
#   j/NN
#   e/NN
#   c/NN
#   t/NN
#   ./.
#    /VB
#   A/DT
#    /JJ
#   c/NN
#   o/NN
#   m/NN
#   m/NN
#   i/NN
#   s/VBP
#   s/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#    /VBZ
#   a/DT
#   d/JJ
#   j/NN
#   u/JJ
#   s/NN
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   l/VBZ
#   a/DT
#   i/JJ
#   m/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk
# /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/JJ
#   s/NN
#    /VBD
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk  /NNP G/NNP r/NN)
#   e/VBZ
#   a/DT
#   t/NN
#    /NN
#   (Chunk B/NNP r/NN)
#   i/NN
#   t/VBP
#   a/DT
#   i/NN
#   n/MD
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /NN
#   (Chunk B/NNP r/NN)
#   i/NN
#   t/VBP
#   i/NN
#   s/VBP
#   h/NN
#   (Chunk  /NNP s/NN)
#   u/NN
#   b/NN
#   j/NN
#   e/NN
#   c/VBP
#   t/NN
#   s/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk
# /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   o/MD
#   r/VB
#   g/VB
#   a/DT
#   n/NN
#   i/NN
#   z/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   d/VBP
#   e/JJ
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   v/NN
#   e/NN
#   n/IN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBD
#   8/CD
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP F/NNP e/NN)
#   b/NN
#   r/NN
#   u/IN
#   a/DT
#   r/NN
#   y/NN
#   (Chunk
# /NNP)
#   l/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   ,/,
#    /VBP
#   i/JJ
#   s/VBP
#    /JJ
#   n/JJ
#   o/NN
#   w/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   t/VBP
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   (Chunk L/NNP o/NN)
#   n/NN
#   d/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   a/DT
#   n/JJ
#   s/NN
#   a/DT
#   c/JJ
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#    /NN
#   b/NN
#   u/JJ
#   s/NN
#   i/NN
#   n/VBP
#   e/NN
#   s/NN
#   s/NN
#   ./.
#    /NN
#   I/PRP
#   t/VBP
#    /JJ
#   i/NN
#   s/VBP
#    /NN
#   i/NN
#   (Chunk n/VBP
# /NNP)
#   m/FW
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   p/NN
#   e/NN
#   c/VBP
#   t/NN
#   s/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   s/NN
#   i/NN
#   r/VBP
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   o/NN
#   u/JJ
#   n/JJ
#   d/NN
#   a/DT
#   r/NN
#   y/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   n/VBP
#   e/NN
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#
# /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP B/NNP r/NN)
#   i/NN
#   t/VBP
#   i/NN
#   s/VBP
#   h/NN
#    /NN
#   (Chunk P/NNP r/NN)
#   o/NN
#   v/NN
#   i/NN
#   n/VBP
#   c/NN
#   e/NN
#   s/JJ
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP n/NN)
#   o/NN
#   r/NN
#   t/NN
#   h/NN
#   w/NN
#   e/NN
#   s/NN
#   t/NN
#   ,/,
#    /VB
#   a/DT
#   s/JJ
#   (Chunk  /NNP d/NN)
#   e/NN
#   s/NN
#   i/NN
#   g/VBP
#   n/IN
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   v/NN
#   e/NN
#   n/IN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk
# /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBD
#   1/CD
#   5/CD
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP J/NNP)
#   u/JJ
#   n/NN
#   e/NN
#   ,/,
#    /VBD
#   1/CD
#   8/CD
#   4/CD
#   6/CD
#   ,/,
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP e/NN)
#   s/NN
#   p/NN
#   e/IN
#   c/NN
#   i/VBP
#   a/DT
#   l/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP s/NN)
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk
# /NNP T/NNP e/NN)
#   r/NN
#   r/NN
#   i/NN
#   t/VBP
#   o/JJ
#   r/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP W/NNP)
#   a/DT
#   s/JJ
#   h/NN
#   i/NN
#   n/VBP
#   g/NN
#   t/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP B/NNP r/NN)
#   i/NN
#   t/VBP
#   i/NN
#   s/VBP
#   h/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   s/NN
#   s/NN
#   e/NN
#   s/VBD
#   s/JJ
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP n/NN)
#   o/NN
#   r/NN
#   t/NN
#   h/NN
#   ,/,
#   (Chunk  /NNP)
#   s/VBD
#   h/JJ
#   o/JJ
#   u/JJ
#   l/NN
#   d/NN
#
# /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   a/DT
#   c/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   r/NN
#   k/NN
#   e/NN
#   d/NN
#   ./.
#    /NN
#   I/PRP
#    /VBP
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   f/NN
#   o/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP s/NN)
#   u/NN
#   b/NN
#   j/NN
#   e/NN
#   c/VBP
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP y/NNP)
#   o/MD
#   u/VB
#   r/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   i/NN
#   c/VBP
#   e/NN
#   ./.
#
# /CC
#
# /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#    /NN
#   (Chunk F/NNP)
#   r/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   i/NN
#   e/VBP
#   n/JJ
#   d/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   o/IN
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#   ./.
#    /CC
#   (Chunk T/NNP)
#   h/VBP
#   e/JJ
#   (Chunk
# /NNP e/NN)
#   (Chunk x/NNP t/NN)
#   e/NN
#   n/IN
#   s/NN
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NNS
#   m/VBP
#   e/JJ
#   r/NN
#   c/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   n/NN
#   t/NN
#   r/NN
#   y/NN
#   (Chunk  /NNP m/NN)
#   i/NN
#   g/VBP
#   h/NN
#   t/NN
#   ,/,
#    /VBP
#   i/JJ
#   t/VBP
#    /NN
#   i/NN
#   (Chunk s/VBP
# /NNP)
#   c/VBP
#   o/JJ
#   n/JJ
#   c/NN
#   e/NN
#   i/JJ
#   v/VBP
#   e/JJ
#   d/NN
#   ,/,
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/NN
#   e/VBZ
#   a/DT
#   s/JJ
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   m/NN
#   e/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   n/JJ
#   e/NN
#   c/NNS
#   e/VBP
#   s/JJ
#   s/NN
#   a/DT
#   r/NN
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   t/IN
#   r/NN
#   i/NN
#   c/VBP
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   u/JJ
#   t/NN
#   u/IN
#   a/DT
#   l/NN
#
# /VBZ
#   a/DT
#   d/NN
#   v/NN
#   a/DT
#   n/JJ
#   t/NN
#   a/DT
#   g/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP b/NN)
#   o/NN
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   i/NN
#   e/VBP
#   s/NN
#   ./.
#    /JJ
#   (Chunk W/NNP i/NN)
#   t/VBP
#   h/NN
#    /VBP
#   a/DT
#    /JJ
#   v/NN
#   i/NN
#   e/VBP
#   w/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   i/JJ
#   s/VBP
#    /JJ
#   o/NN
#   b/NN
#   j/NN
#   e/NN
#   c/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   s/VBD
#   o/JJ
#   m/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   o/NN
#   g/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#
# /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP m/NN)
#   a/DT
#   d/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /JJ
#   n/JJ
#   e/NN
#   g/NN
#   o/IN
#   t/NN
#   i/VBP
#   a/DT
#   t/NN
#   i/NN
#   n/VBP
#   g/NN
#    /VBP
#   a/DT
#    /NN
#   t/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP c/NN)
#   o/NN
#   m/NN
#   m/NN
#   e/NN
#   r/NN
#   c/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   v/NN
#   i/NN
#   g/VBP
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/NN
#   ./.
#
# /JJ
#
# /NN
#   I/PRP
#   n/VBP
#   d/JJ
#   e/NN
#   p/NN
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   n/JJ
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   v/VBZ
#   a/DT
#   l/NN
#   u/NN
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   r/NN
#   a/DT
#   d/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP S/NNP)
#   p/IN
#   a/DT
#   i/NN
#   n/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBZ
#   e/FW
#   (Chunk  /NNP)
#   h/VBD
#   a/DT
#   v/NN
#   e/NN
#    /NN
#   i/NN
#   m/VBP
#   p/NN
#   o/NN
#   r/NN
#   t/VBD
#   a/DT
#   n/JJ
#   t/NN
#   (Chunk  /NNP p/NN)
#   o/NN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#   (Chunk
# /NNP r/NN)
#   e/NN
#   l/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#    /NN
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   o/IN
#   w/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   u/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP)
#   n/IN
#   e/NN
#   i/NN
#   g/VBP
#   h/NN
#   b/NN
#   o/NN
#   r/NN
#   h/NN
#   o/JJ
#   o/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   s/VBP
#   l/NN
#   a/DT
#   n/JJ
#   d/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP u/NN)
#   b/VBD
#   a/DT
#
# /NN
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP P/NNP)
#   o/MD
#   r/VB
#   t/JJ
#   o/NN
#   (Chunk  /NNP R/NNP i/NN)
#   c/VBP
#   o/NN
#   ./.
#    /NN
#   I/PRP
#    /VBP
#   a/DT
#   m/NN
#    /NN
#   h/VBD
#   a/DT
#   p/NN
#   p/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   n/JJ
#   n/NN
#   o/NN
#   u/JJ
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP s/NN)
#   i/NN
#   n/VBP
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   l/VBZ
#   a/DT
#   s/JJ
#   t/NN
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#
# /NN
#   a/DT
#   t/NN
#   t/NN
#   e/NN
#   m/NN
#   p/NN
#   t/NN
#   s/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP m/NN)
#   a/DT
#   d/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   y/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/FW
#   a/DT
#   u/JJ
#   t/NN
#   h/NN
#   o/IN
#   r/NN
#   i/NN
#   z/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP p/NN)
#   e/NN
#   d/NN
#   i/NN
#   t/VBP
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk
# /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk  /NNP e/NN)
#   i/NN
#   t/VBP
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   l/NN
#   o/IN
#   n/JJ
#   i/NN
#   e/VBP
#   s/NN
#   ./.
#    /CC
#   (Chunk S/NNP)
#   h/VBP
#   o/JJ
#   u/JJ
#   l/NN
#   d/NN
#    /VBZ
#   a/DT
#   n/JJ
#   y/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   v/NN
#   e/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   n/NN
#   i/NN
#   f/VBP
#   e/NN
#   s/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk
# /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   i/NN
#   n/VBP
#    /JJ
#   o/NN
#   u/JJ
#   r/NN
#   (Chunk  /NNP l/NN)
#   i/NN
#   m/VBP
#   i/NN
#   t/NN
#   s/NN
#   ,/,
#    /VB
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   e/VBZ
#   a/DT
#   n/JJ
#   s/NN
#    /VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   m/NNS
#   m/VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   l/VBP
#   l/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   g/VBP
#   o/JJ
#   r/NN
#   o/NN
#   u/JJ
#   s/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP e/NN)
#   r/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk
# /NNP t/NN)
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   p/NN
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#    /NN
#   i/NN
#   t/NN
#   ./.
#    /CC
#   (Chunk S/NNP)
#   e/VBP
#   v/NN
#   e/NN
#   r/VBZ
#   a/DT
#   l/NN
#    /VBZ
#   a/DT
#   n/JJ
#   n/NN
#   o/IN
#   y/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   c/JJ
#   c/NNS
#   u/JJ
#   r/NN
#   r/NN
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   s/JJ
#   (Chunk  /NNP h/NN)
#   a/DT
#   v/NN
#   e/NN
#   (Chunk  /NNP)
#   t/VBZ
#   a/DT
#   k/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP p/NN)
#   l/NN
#   a/DT
#   c/NN
#   e/NN
#    /VBZ
#   a/DT
#   t/NN
#    /NN
#   (Chunk H/NNP)
#   a/DT
#   v/NN
#   a/DT
#   n/NN
#   a/DT
#   ,/,
#    /NN
#   o/NN
#   r/NN
#
# /NN
#   i/NN
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP v/NN)
#   i/NN
#   c/VBP
#   i/JJ
#   n/VBP
#   i/JJ
#   t/VBP
#   y/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   s/VBP
#   l/NN
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP u/NN)
#   b/NN
#   a/DT
#   ,/,
#    /NN
#   b/NN
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP o/NN)
#   u/JJ
#   r/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   t/VBP
#   i/JJ
#   z/VBP
#   e/JJ
#   n/JJ
#   s/NN
#    /VBD
#   a/DT
#   n/JJ
# ...
#   a/DT
#   d/JJ
#   m/NN
#   i/NN
#   n/VBP
#   i/NN
#   s/VBP
#   t/NN
#   r/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP l/NN)
#   e/NN
#   g/NN
#   i/NN
#   s/VBP
#   l/NN
#   a/DT
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   ,/,
#   (Chunk  /NNP)
#   g/VBZ
#   u/RP
#   a/DT
#   r/NN
#   d/NN
#   s/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk
# /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   n/JJ
#   g/NN
#   e/NN
#   r/NN
#   o/NN
#   u/JJ
#   s/NN
#   (Chunk  /NNP t/NN)
#   e/NN
#   m/NN
#   p/NN
#   t/VBD
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#    /NN
#   i/NN
#   n/VBP
#   c/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   o/VBZ
#   v/FW
#   e/FW
#   r/NN
#   f/NN
#   l/NN
#   o/IN
#   w/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   v/NN
#   e/NN
#   n/JJ
#   u/JJ
#   e/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk
# /NNP e/NN)
#   (Chunk x/NNP)
#   e/VBZ
#   c/JJ
#   u/JJ
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   i/JJ
#   n/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   s/NN
#    /VBZ
#   a/DT
#   n/JJ
#    /NN
#   u/JJ
#   n/JJ
#   s/NN
#   l/NN
#   e/NN
#   e/IN
#   p/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   t/JJ
#   c/NN
#   h/NN
#   f/JJ
#   u/JJ
#   l/NN
#   n/JJ
#   e/NN
#   s/NN
#   s/NN
#    /VBZ
#   a/DT
#   g/NN
#   a/DT
#   i/NN
#   n/MD
#   s/VB
#   t/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   e/NN
#   n/JJ
#   d/NN
#   e/NN
#   n/JJ
#   c/NN
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   a/DT
#   l/NN
#   l/NN
#   (Chunk
# /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP p/NN)
#   e/NN
#   n/IN
#   d/NN
#   i/NN
#   t/VBP
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP e/NN)
#   (Chunk x/NNP t/NN)
#   r/VBZ
#   a/DT
#   v/NN
#   a/DT
#   g/NN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   w/VBP
#   h/NN
#   i/NN
#   l/VBP
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   y/NN
#    /VBZ
#   a/DT
#   r/NN
#   e/NN
#    /VBZ
#   a/DT
#   d/JJ
#   m/NN
#   i/NN
#   t/VBP
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP e/NN)
#   l/NN
#   e/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   a/DT
#   r/NN
#   y/NN
#   (Chunk
# /NNP p/NN)
#   o/NN
#   l/NN
#   i/NN
#   t/VBP
#   i/NN
#   c/VBP
#   a/DT
#   l/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   i/NN
#   e/VBP
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   m/VBZ
#   a/DT
#   y/NN
#   ,/,
#    /VBP
#   I/PRP
#    /VBP
#   t/JJ
#   r/NN
#   u/JJ
#   s/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   e/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   e/VBP
#   m/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   s/JJ
#    /NN
#   p/NN
#   r/NN
#   o/NN
#   p/NN
#   e/NN
#   r/NN
#   l/NN
#   y/NN
#    /VBZ
#   a/DT
#   d/NN
#   v/NN
#   e/NN
#   r/NN
#   t/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   r/NN
#   g/NN
#   e/NN
#   d/NN
#
# /NN
#   i/NN
#   n/VBP
#    /IN
#   v/NN
#   i/NN
#   e/VBP
#   w/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   r/NN
#   e/NN
#    /NN
#   i/NN
#   m/VBP
#   p/NN
#   r/NN
#   e/NN
#   s/VBD
#   s/JJ
#   i/NN
#   v/VBP
#   e/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   n/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP)
#   n/CC
#   e/JJ
#   c/NNS
#   e/VBP
#   s/JJ
#   s/NN
#   i/NN
#   t/VBP
#   y/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /NN
#   i/NN
#   (Chunk s/VBP  /NNP d/NN)
#   i/NN
#   r/VBP
#   e/NN
#   c/NNS
#   t/VBP
#   l/JJ
#   y/NN
#   (Chunk
# /NNP s/NN)
#   u/JJ
#   g/NN
#   g/NN
#   e/NN
#   s/NN
#   t/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   s/NN
#   i/NN
#   d/VBP
#   e/NN
#   r/NN
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   w/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   e/NN
#   s/NN
#   e/NN
#   n/JJ
#   t/NN
#   e/NN
#   d/NN
#   ./.
#
# /JJ
#
# /JJ
#   (Chunk S/NNP i/NN)
#   n/VBP
#   c/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   d/JJ
#   j/NN
#   o/NN
#   u/JJ
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP V/NNP i/NN)
#   c/VBP
#   e/SYM
#   -/:
#   (Chunk P/NNP r/NN)
#   e/NN
#   s/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP U/NNP n/NN)
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk  /NNP S/NNP)
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   s/NN
#   (Chunk
# /NNP)
#   h/VBZ
#   a/DT
#   s/JJ
#    /NN
#   p/VBZ
#   a/DT
#   s/JJ
#   s/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   c/JJ
#   e/NN
#   n/JJ
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP e/NN)
#   a/DT
#   r/NN
#   t/NN
#   h/NN
#   ,/,
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   o/NN
#   u/JJ
#   t/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP e/NN)
#   n/RB
#   t/JJ
#   e/NN
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   p/NN
#   o/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP d/NN)
#   u/JJ
#   t/NN
#   i/NN
#   e/VBP
#   s/JJ
#   (Chunk
# /NNP o/NN)
#   f/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   s/VBZ
#   t/VB
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#   (Chunk  /NNP h/NN)
#   e/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   d/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   l/NN
#   l/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP v/NN)
#   o/NN
#   i/NN
#   c/VBP
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP h/NN)
#   i/NN
#   (Chunk s/VBP  /NNP)
#   c/VBP
#   o/JJ
#   u/JJ
#   n/NN
#   t/NN
#   r/NN
#   y/NN
#   m/NN
#   e/NN
#   n/NN
#   ./.
#   (Chunk
# /VB H/NNP)
#   a/DT
#   v/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   o/VBZ
#   c/JJ
#   c/NNS
#   u/JJ
#   p/NN
#   i/NN
#   e/VBP
#   d/NN
#    /VBP
#   a/DT
#   l/NN
#   m/NN
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   t/NN
#   i/NN
#   n/VBP
#   u/JJ
#   o/NN
#   u/JJ
#   s/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP f/NN)
#   o/NN
#   r/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   r/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   n/JJ
#    /NN
#   t/NN
#   h/NN
#   i/JJ
#   r/VBP
#   t/JJ
#   y/NN
#   (Chunk  /NNP y/NNP)
#   e/VBZ
#   a/DT
#   r/NN
#   s/NN
#    /VBZ
#   a/DT
#    /JJ
#   s/NN
#   e/VBZ
#   a/DT
#   t/JJ
#    /NN
#   i/NN
#   n/VBP
#
# /JJ
#   o/NN
#   n/JJ
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   r/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   t/JJ
#   h/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   w/NN
#   o/NN
#   (Chunk  /NNP H/NNP)
#   o/MD
#   u/VB
#   s/JJ
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   v/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP h/NN)
#   i/NN
#   s/VBP
#    /IN
#   s/NN
#   i/NN
#   n/VBP
#   g/NN
#   u/JJ
#   l/NN
#   a/DT
#   r/NN
#   (Chunk
# /NNP p/NN)
#   u/JJ
#   r/NN
#   i/NN
#   t/VBP
#   y/NN
#    /VBP
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   s/VBP
#   d/NN
#   o/NN
#   m/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/NN
#   b/NN
#   o/NN
#   u/JJ
#   n/JJ
#   d/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   f/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/NN
#   i/NN
#   v/VBP
#   e/NN
#   r/NN
#   s/VBD
#   a/DT
#   l/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   s/NN
#   p/NN
#   e/NN
#   c/NN
#   t/NN
#   ,/,
#   (Chunk  /NNP h/NN)
#   i/NN
#   (Chunk s/VBP
# /NNP)
#   f/VBP
#   a/DT
#   i/JJ
#   l/NN
#   i/NN
#   n/VBP
#   g/NN
#    /NN
#   h/NN
#   e/VBZ
#   a/DT
#   l/NN
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   s/JJ
#    /NN
#   w/VBD
#   a/DT
#   t/JJ
#   c/NN
#   h/NN
#   e/NN
#   d/NN
#    /NN
#   b/NN
#   y/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   n/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   i/JJ
#   n/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   l/NN
#   i/VBP
#   c/VBP
#   i/JJ
#   t/VBP
#   u/JJ
#   d/NN
#   e/NN
#   ./.
#    /JJ
#   (Chunk H/NNP i/NN)
#   s/VBP
#    /JJ
#   l/NN
#   o/NN
#   s/NN
#   s/NN
#   (Chunk
# /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   n/NN
#   t/NN
#   r/NN
#   y/NN
#   ,/,
#   (Chunk  /NNP)
#   u/JJ
#   n/RB
#   d/VBP
#   e/JJ
#   r/NN
#    /VBD
#   a/DT
#   l/NN
#   l/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP c/NN)
#   i/NN
#   r/VBP
#   c/NN
#   u/JJ
#   m/NN
#   s/NN
#   t/VBD
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP)
#   h/VBZ
#   a/DT
#   s/NN
#    /NN
#   b/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP j/NN)
#   u/JJ
#   s/NN
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   g/VBD
#   a/DT
#   r/NN
#   d/NN
#   e/NN
#   d/NN
#    /VBZ
#   a/DT
#   s/JJ
#
# /NN
#   i/NN
#   r/VBP
#   r/NN
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   ./.
#
# /JJ
#
# /NN
#   I/PRP
#   n/VBP
#    /JJ
#   c/NN
#   o/NN
#   m/NN
#   p/NN
#   l/NN
#   i/VBZ
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP w/NN)
#   i/NN
#   t/VBP
#   h/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBZ
#   a/DT
#   c/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP)
#   o/MD
#   n/VB
#   g/JJ
#   r/NN
#   e/NN
#   s/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP M/NNP)
#   a/DT
#   r/NN
#   c/NN
#   h/NN
#    /JJ
#   2/CD
#   ,/,
#    /VBD
#   1/CD
#   8/CD
#   5/CD
#   3/CD
#   ,/,
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP)
#   o/VBZ
#   a/DT
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP o/NN)
#   f/NN
#   f/NN
#   i/NN
#   c/VBP
#   e/NN
#   (Chunk
# /NNP)
#   w/VBZ
#   a/DT
#   s/JJ
#    /NN
#   a/DT
#   d/JJ
#   m/NN
#   i/NN
#   n/VBP
#   i/NN
#   s/VBP
#   t/NN
#   e/NN
#   r/NN
#   e/NN
#   d/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP h/NN)
#   i/NN
#   m/VBP
#    /JJ
#   o/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBD
#   2/CD
#   4/CD
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/VBD
#   a/DT
#   t/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   n/JJ
#   t/NN
#   h/NN
#    /VBZ
#   a/DT
#   t/NN
#   (Chunk  /VBZ A/NNP r/NN)
#   i/NN
#   a/DT
#   d/NN
#   n/JJ
#   e/NN
#   (Chunk  /NNP e/NN)
#   s/NN
#   t/VBD
#   a/DT
#   t/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   n/FW
#   e/VBZ
#   a/DT
#   r/NN
#   (Chunk
# /NNP M/NNP)
#   a/DT
#   t/NN
#   a/DT
#   n/JJ
#   z/NN
#   a/DT
#   s/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   s/VBP
#   l/NN
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP C/NNP u/NN)
#   b/VBZ
#   a/DT
#   ;/:
#    /NN
#   b/NN
#   u/JJ
#   t/NN
#   (Chunk  /NNP h/NN)
#   i/NN
#   s/VBP
#    /JJ
#   s/NN
#   t/NN
#   r/NN
#   e/NN
#   n/JJ
#   g/NN
#   t/NN
#   h/NN
#   (Chunk  /NNP g/NN)
#   r/NN
#   a/DT
#   d/NN
#   u/IN
#   a/DT
#   l/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   c/VBP
#   l/NN
#   i/NN
#   n/VBP
#   e/NN
#   d/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk
# /NNP)
#   w/VBZ
#   a/DT
#   s/JJ
#    /NN
#   h/VBD
#   a/DT
#   r/NN
#   d/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP s/NN)
#   u/JJ
#   f/JJ
#   f/NN
#   i/NN
#   c/VBP
#   i/NN
#   e/VBP
#   n/JJ
#   t/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   e/VBZ
#   n/FW
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   i/NN
#   m/VBP
#    /JJ
#   t/NN
#   o/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   t/NN
#   u/JJ
#   r/NN
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP h/NN)
#   i/NN
#   s/VBP
#    /NN
#   h/NN
#   o/JJ
#   m/NN
#   e/NN
#    /NN
#   i/NN
#   n/VBP
#    /PDT
#   (Chunk A/NNP l/NN)
#   a/DT
#   b/NN
#   a/DT
#   m/NN
#   a/DT
#   ,/,
#
# /JJ
#   w/NN
#   h/NN
#   e/NN
#   r/NN
#   e/NN
#   ,/,
#   (Chunk  /NNP)
#   o/MD
#   (Chunk n/VB  /NNP t/NN)
#   h/NN
#   e/NN
#    /VBD
#   1/CD
#   8/CD
#   t/NN
#   h/NN
#   (Chunk  /NNP)
#   d/VBZ
#   a/DT
#   y/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#    /IN
#   A/DT
#   p/NN
#   r/NN
#   i/NN
#   l/NN
#   ,/,
#    /VBP
#   i/JJ
#   n/VBP
#    /JJ
#   t/NN
#   h/NN
#   e/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   s/NN
#   t/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   l/JJ
#   m/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP p/NN)
#   e/VBZ
#   a/DT
#   c/JJ
#   e/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   y/NN
#   ,/,
#   (Chunk  /NNP h/NN)
#   i/NN
#   s/VBP
#
# /JJ
#   l/NN
#   o/NN
#   n/JJ
#   g/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   e/VBZ
#   m/NN
#   i/NN
#   n/VBP
#   e/NN
#   n/JJ
#   t/NN
#   l/NN
#   y/NN
#   (Chunk  /NNP)
#   u/JJ
#   s/NN
#   e/NN
#   f/NN
#   u/JJ
#   l/NN
#   (Chunk  /NNP)
#   c/VBZ
#   a/DT
#   r/NN
#   e/NN
#   e/NN
#   r/NN
#   (Chunk  /NNP)
#   w/VBZ
#   a/DT
#   s/JJ
#    /NN
#   t/NN
#   e/NN
#   r/NN
#   m/NN
#   i/NN
#   n/VBP
#   a/DT
#   t/NN
#   e/NN
#   d/NN
#   ./.
#    /JJ
#   (Chunk E/NNP)
#   n/MD
#   t/VB
#   e/NN
#   r/NN
#   t/IN
#   a/DT
#   i/JJ
#   n/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   u/JJ
#   n/JJ
#   l/NN
#   i/NN
#   m/VBP
#   i/NN
#   t/VBP
#   e/NN
#   d/NN
#   (Chunk
# /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   f/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#   (Chunk  /NNP i/NN)
#   n/VBP
#    /JJ
#   y/NN
#   o/NN
#   u/JJ
#   r/NN
#    /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   l/NN
#   l/NN
#   i/NN
#   g/VBP
#   e/NN
#   n/JJ
#   t/NN
#    /VBD
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   t/JJ
#   r/NN
#   i/NN
#   o/VBP
#   t/NN
#   i/NN
#   (Chunk c/VBP  /NNP d/NN)
#   e/NN
#   v/NN
#   o/IN
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP p/NN)
#   u/NN
#   b/IN
#   l/NN
#   i/NN
#   c/VBP
#
# /NN
#   i/NN
#   n/VBP
#   t/NN
#   e/NN
#   r/NN
#   e/NN
#   s/NN
#   t/NN
#   ,/,
#    /VB
#   a/DT
#   n/JJ
#   d/NN
#    /NN
#   b/IN
#   e/NN
#   i/NN
#   n/VBP
#   g/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/JJ
#   s/NN
#   c/NN
#   i/NN
#   o/VBP
#   u/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP n/NN)
#   o/NN
#   (Chunk  /NNP m/NN)
#   o/NN
#   t/NN
#   i/NN
#   v/VBP
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP)
#   p/VBZ
#   a/DT
#   r/NN
#   t/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /FW
#   a/DT
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#
# /NN
#   i/NN
#   n/VBP
#   s/NN
#   e/NN
#   p/VBZ
#   a/DT
#   r/NN
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP f/NN)
#   r/NN
#   o/IN
#   m/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP h/NN)
#   o/NN
#   n/NN
#   o/NN
#   r/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#    /VBD
#   a/DT
#   d/NN
#   v/NN
#   a/DT
#   n/JJ
#   c/NN
#   e/NN
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP m/NN)
#   y/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   u/JJ
#   n/NN
#   t/NN
#   r/NN
#   y/NN
#   ,/,
#    /VBP
#   I/PRP
#    /VBP
#   h/JJ
#   o/JJ
#   p/NN
#   e/NN
#    /NN
#   i/NN
#   (Chunk t/VBP  /NNP)
#   m/FW
#   a/DT
#   y/NN
#    /NN
#   b/NN
#   e/NN
#   (Chunk
# /NNP m/NN)
#   y/NN
#   (Chunk  /NNP p/NN)
#   r/NN
#   i/NN
#   v/VBP
#   i/NN
#   l/VBP
#   e/NN
#   g/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   s/NN
#   e/NN
#   r/NN
#   v/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk  /NNP s/NN)
#   e/NN
#   c/NN
#   u/JJ
#   r/NN
#   e/NN
#   (Chunk  /NNP)
#   n/CC
#   o/JJ
#   t/NN
#   (Chunk  /NNP)
#   o/VBZ
#   n/JJ
#   l/NN
#   y/NN
#   (Chunk  /NNP y/NNP)
#   o/MD
#   u/VB
#   r/NN
#   (Chunk  /NNP c/NN)
#   o/NN
#   r/NN
#   d/NN
#   i/VBZ
#   a/DT
#   l/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   o/JJ
#   p/NN
#   e/NN
#   r/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/IN
#    /NN
#   i/NN
#   n/VBP
#
# /NN
#   g/NN
#   r/NN
#   e/VBZ
#   a/DT
#   t/NN
#   (Chunk  /NNP p/NN)
#   u/NN
#   b/IN
#   l/NN
#   i/NN
#   (Chunk c/VBP  /NNP m/NN)
#   e/VBZ
#   a/DT
#   s/NN
#   u/JJ
#   r/NN
#   e/NN
#   s/NN
#   ,/,
#   (Chunk  /NNP b/NN)
#   u/NN
#   t/NN
#    /VBZ
#   a/DT
#   l/NN
#   s/NN
#   o/NN
#   (Chunk  /NNP t/NN)
#   h/NN
#   o/JJ
#   s/NN
#   e/NN
#   (Chunk  /NNP r/NN)
#   e/NN
#   l/VBZ
#   a/DT
#   t/NN
#   i/NN
#   o/VBP
#   n/JJ
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP m/NN)
#   u/JJ
#   t/NN
#   u/IN
#   a/DT
#   l/NN
#   (Chunk  /NNP)
#   c/VBZ
#   o/JJ
#   n/IN
#   f/NN
#   i/NN
#   d/VBP
#   e/NN
#   n/JJ
#   c/NN
#   e/NN
#    /VBZ
#   a/DT
#   n/JJ
#   d/NN
#   (Chunk
# /NNP r/NN)
#   e/NN
#   g/VBD
#   a/DT
#   r/NN
#   d/NN
#   (Chunk  /NNP w/NN)
#   h/NN
#   i/JJ
#   c/VBP
#   h/JJ
#    /NN
#   i/NN
#   t/VBP
#    /NN
#   i/NN
#   s/VBP
#    /PDT
#   a/DT
#   l/NN
#   w/WRB
#   a/DT
#   y/NN
#   s/NN
#   (Chunk  /NNP s/NN)
#   o/NN
#   (Chunk  /NNP d/NN)
#   e/NN
#   s/NN
#   i/NN
#   r/VBP
#   a/DT
#   b/NN
#   l/NN
#   e/NN
#   (Chunk  /NNP t/NN)
#   o/NN
#   (Chunk  /NNP)
#   c/VBZ
#   u/JJ
#   l/NN
#   t/NN
#   i/NN
#   v/VBP
#   a/DT
#   t/NN
#   e/NN
#   (Chunk  /NNP b/NN)
#   e/NN
#   t/NN
#   w/NN
#   e/NN
#   e/NN
#   n/JJ
#   (Chunk  /NNP m/NN)
#   e/NN
#   m/NN
#   b/NN
#   e/NN
#   r/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk
# /NNP c/NN)
#   o/NN
#   o/IN
#   r/NN
#   d/NN
#   i/NN
#   n/VBP
#   a/DT
#   t/NN
#   e/NN
#    /NN
#   b/NN
#   r/NN
#   a/DT
#   n/JJ
#   c/NN
#   h/NN
#   e/NN
#   s/NN
#   (Chunk  /NNP)
#   o/VBZ
#   f/JJ
#   (Chunk  /NNP t/NN)
#   h/NN
#   e/NN
#   (Chunk  /NNP G/NNP)
#   o/MD
#   v/VB
#   e/NN
#   r/NN
#   n/JJ
#   m/NN
#   e/NN
#   n/JJ
#   t/NN
#   ./.)
